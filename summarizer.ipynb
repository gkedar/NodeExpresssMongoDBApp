# %% [markdown]
# <a href="https://colab.research.google.com/github/gkedar/NodeExpresssMongoDBApp/blob/master/summarizer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install summarizer
# !pip3 install spacy
# !pip3 install transformers
# !pip3 install bert-extractive-summarizer
# !pip3 install sentence-transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.1/280.1 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for summarizer: filename=summarizer-0.0.7-py2.py3-none-any.whl size=284209 sha256=5ca62667b8c4d8b4377fe8e2c95fdec93e775e0e7373a67063bda3870ad57ea5
#   Stored in directory: /root/.cache/pip/wheels/20/bb/2d/1fe057c2f729818a5f28c312c3667e8b9d5cfd4af4a39895e7
# Successfully built summarizer
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.3/163.3 kB 2.5 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade spacy[cuda111,transformers]
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.9/197.9 kB 992.8 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.1/101.1 MB 4.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 34.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 314.0/314.0 kB 14.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 28.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 17.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 26.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 1.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.1 MB/s eta 0:00:00
# ...

# %%
# !pip install jsonlines
# !python -m spacy download en_core_web_lg
# !python -m spacy download en_core_web_sm

# !wget https://andrewhalterman.com/files/cleaned_masdar.jsonl
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/cupy/_environment.py:447: UserWarning:
# --------------------------------------------------------------------------------
#
#   CuPy may not function correctly because multiple CuPy packages are installed
#   in your environment:
#
#     cupy-cuda111, cupy-cuda12x
#
#   Follow these steps to resolve this issue:
#
#     1. For all packages listed above, run the following command to remove all
#        existing CuPy installations:
#
#          $ pip uninstall <package_name>
#
#       If you previously installed CuPy via conda, also run the following:
#
#          $ conda uninstall cupy
#
#     2. Install the appropriate CuPy package.
#        Refer to the Installation Guide for detailed instructions.
#
#          https://docs.cupy.dev/en/stable/install.html
#
# --------------------------------------------------------------------------------
#
#   warnings.warn(f'''
# /usr/local/lib/python3.10/dist-packages/cupy/_environment.py:447: UserWarning:
# ...

# %%
import jsonlines

from tqdm.autonotebook import tqdm
import jsonlines
import re

import spacy
from spacy import displacy

# %%
nlp = spacy.load("en_core_web_lg")
nlp_sm = spacy.load("en_core_web_sm")
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:441: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(

# %%
text = """
Part Label: Suspension Control Arm

Extended Description:   Suspension Control Arm front right lower
Invoice Product Description: Control Arm
Ball Joint Included: No
Bushing Material: Rubber
Bushings Included: Yes
Color: Black
Control Arm Material: Stamped Steel
Finish: Paint
Grade Type: Regular
Grease Fitting Included: No
Mounting Hardware Included: No
Pre-Greased: No
"""

doc = nlp(text)
len(doc)
# Out:
# 80

# %%
displacy.render(doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr"><br>Part Label: Suspension Control Arm<br><br>Extended Description:
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Suspension Control Arm
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  front right lower<br>Invoice Product Description: Control Arm<br>Ball Joint Included: No<br>Bushing Material: Rubber<br>Bushings Included: Yes<br>Color: Black<br>Control Arm Material: Stamped Steel<br>Finish: Paint<br>Grade Type: Regular<br>Grease Fitting Included: No<br>Mounting Hardware Included: No<br>Pre-Greased: No<br></div></span>

# %%
spacy.explain("PRODUCT")
# Out:
# 'Objects, vehicles, foods, etc. (not services)'

# %%
just_text = [text]
docs = list(tqdm(nlp.pipe(just_text), total=len(just_text)))
# Out:
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
[(i.text, i.ent_iob_ + "-" + i.ent_type_) for i in doc[0:30]]
# Out:
# [('\n', 'O-'),
#  ('Part', 'O-'),
#  ('Label', 'O-'),
#  (':', 'O-'),
#  ('Suspension', 'O-'),
#  ('Control', 'O-'),
#  ('Arm', 'O-'),
#  ('\n\n', 'O-'),
#  ('Extended', 'O-'),
#  ('Description', 'O-'),
#  (':', 'O-'),
#  ('  ', 'O-'),
#  ('Suspension', 'B-PRODUCT'),
#  ('Control', 'I-PRODUCT'),
#  ('Arm', 'I-PRODUCT'),
#  ('front', 'O-'),
#  ('right', 'O-'),
#  ('lower', 'O-'),
#  ('\n', 'O-'),
#  ('Invoice', 'O-'),
#  ('Product', 'O-'),
#  ('Description', 'O-'),
#  (':', 'O-'),
#  ('Control', 'O-'),
#  ('Arm', 'O-'),
#  ('\n', 'O-'),
#  ('Ball', 'O-'),
#  ('Joint', 'O-'),
#  ('Included', 'O-'),
#  (':', 'O-')]

# %%
from collections import Counter

all_orgs = []
for d in docs:
    orgs = [ent.text for ent in d.ents if ent.label_ == "PRODUCT"]
    all_orgs.extend(orgs)

Counter(all_orgs).most_common(15)
# Out:
# [('Suspension Control Arm', 1)]

# %%
doc = nlp(text)
sent = list(doc.sents)[1]
displacy.render(sent, style="dep", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="07d40c4e814a4666a934dc8a2f126ef8-0" class="displacy" width="6350" height="749.5" direction="ltr" style="max-width: none; height: 749.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">right</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">lower</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="659.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">
# ...

# %%
displacy.render(doc, style="ent", jupyter=True)

# %%
tok = doc  # "Aleppo"
print(tok)

def loc_to_verb(tok):
    verb_phrase = []
    # first, iterate through all the ancesters of the token
    for i in tok.ancestors:
        # when you get to a verb (using a POS tag)...
        if i.pos_ == "VERB":
            # ...add the verb to the verb phrase list
            verb_phrase.append(i)
            # then, also add the direct object(s) of the verb, as long as the original token
            # is in the same subtree as the direct object
            verb_phrase.extend([j for j in i.children if j.dep_ == "dobj" and tok in i.subtree])
            # we only want the first verb, so stop after we find one
            break
    # expand out the verb phrase to get modifiers ("amod") of the direct object
    for i in verb_phrase:
        for j in i.children:
            if j.dep_ == "amod":
                verb_phrase.append(j)

    # sort the tokens by their position in the original sentence
    new_list = sorted(verb_phrase, key=lambda x: x.i)
    # join them together with the correct whitespace and return
    return ''.join([i.text_with_ws for i in new_list]).strip()

loc_to_verb(tok)
# Out:
# Part Label: Suspension Control Arm
#
# Extended Description:   Suspension Control Arm front right lower
# Invoice Product Description: Control Arm
# Ball Joint Included: No
# Bushing Material: Rubber
# Bushings Included: Yes
# Color: Black
# Control Arm Material: Stamped Steel
# Finish: Paint
# Grade Type: Regular
# Grease Fitting Included: No
# Mounting Hardware Included: No
# Pre-Greased: No
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-aa89dff5ad42> in <cell line: 28>()
#      26     return ''.join([i.text_with_ws for i in new_list]).strip()
#      27
# ---> 28 loc_to_verb(tok)
#
# <ipython-input-33-aa89dff5ad42> in loc_to_verb(tok)
#       5     verb_phrase = []
#       6     # first, iterate through all the ancesters of the token
# ----> 7     for i in tok.ancestors:
#       8         # when you get to a verb (using a POS tag)...
# ...

# %%
from summarizer import Summarizer
model = Summarizer()
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/utils/generic.py:309: UserWarning: torch.utils._pytree._register_pytree_node is deprecated. Please use torch.utils._pytree.register_pytree_node instead.
#   _torch_pytree._register_pytree_node(
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
# !python -m spacy download en_core_web_lg
# Out:
# /usr/local/lib/python3.10/dist-packages/cupy/_environment.py:447: UserWarning:
# --------------------------------------------------------------------------------
#
#   CuPy may not function correctly because multiple CuPy packages are installed
#   in your environment:
#
#     cupy-cuda111, cupy-cuda12x
#
#   Follow these steps to resolve this issue:
#
#     1. For all packages listed above, run the following command to remove all
#        existing CuPy installations:
#
#          $ pip uninstall <package_name>
#
#       If you previously installed CuPy via conda, also run the following:
#
#          $ conda uninstall cupy
#
#     2. Install the appropriate CuPy package.
#        Refer to the Installation Guide for detailed instructions.
#
#          https://docs.cupy.dev/en/stable/install.html
#
# --------------------------------------------------------------------------------
#
#   warnings.warn(f'''
# /usr/local/lib/python3.10/dist-packages/cupy/_environment.py:447: UserWarning:
# ...

# %%
text = """
Part Label: Suspension Control Arm

Extended Description:   Suspension Control Arm front right lower
Invoice Product Description: Control Arm
Ball Joint Included: No
Bushing Material: Rubber
Bushings Included: Yes
Color: Black
Control Arm Material: Stamped Steel
Finish: Paint
Grade Type: Regular
Grease Fitting Included: No
Mounting Hardware Included: No
Pre-Greased: No
"""

doc = nlp(text)
for token in doc:
    print(token.text)

for token in doc:
    print(token.text, token.has_vector, token.vector_norm, token.is_oov)
# Out:
# Part
# Label
# :
# Suspension
# Control
# Arm
#
#
#
# Extended
# Description
# :
#
# Suspension
# Control
# Arm
# front
# right
# lower
#
#
# Invoice
# Product
# Description
# :
# Control
# Arm
#
#
# Ball
# Joint
# Included
# :
# No
#
#
# Bushing
# Material
# :
# Rubber
#
#
# Bushings
# Included
# :
# Yes
#
#
# Color
# :
# Black
#
#
# Control
# Arm
# Material
# :
# Stamped
# Steel
#
#
# Finish
# :
# Paint
#
#
# Grade
# Type
# :
# Regular
#
#
# Grease
# Fitting
# Included
# :
# No
#
#
# Mounting
# Hardware
# Included
# :
# No
#
#
# Pre
# -
# Greased
# :
# No
#
#
#
#  False 0.0 True
# Part True 51.828682 False
# Label True 37.352974 False
# : True 86.71291 False
# Suspension True 32.961334 False
# Control True 46.36265 False
# Arm True 48.977283 False
#
#
#  False 0.0 True
# Extended True 34.482464 False
# Description True 35.343178 False
# : True 86.71291 False
#    False 0.0 True
# Suspension True 32.961334 False
# Control True 46.36265 False
# Arm True 48.977283 False
# ...

# %%
text = """
Part Label: Suspension Control Arm And Ball Joint Assembly

Suspension Control Arm and Ball Joint Assembly
Extended Description:   Horquilla con Rotula parte delantera izquierda superior
Extended Description:   Bras de suspension assemble avec joint a rotule avant gauche superieur
Extended Description:   Suspension Control Arm and Ball Joint Assembly front left upper
Invoice Product Description: Bras com joint rotu
Invoice Product Description: Cntrl Arm w Ball Jt
Invoice Product Description: Ens rot brazo contrl
Ball Joint Mounting Type: Press In
Ball Joint Stud Type: Threaded
Bushing Material: Rubber
Bushings Included: Yes
Control Arm Color: Black
Control Arm Material: Forged Steel
Grease Fitting Included: Yes
Mounting Hardware Included: Yes
Pre-Greased: Yes
"""

text = """
Part Label: Suspension Control Arm And Ball Joint Assembly

Suspension Control Arm and Ball Joint Assembly
Extended Description:   Horquilla con Rotula parte delantera izquierda superior
Extended Description:   Bras de suspension assemble avec joint a rotule avant gauche superieur
Extended Description:   Suspension Control Arm and Ball Joint Assembly front left upper
Invoice Product Description: Bras com joint rotu
Invoice Product Description: Cntrl Arm w Ball Jt
Invoice Product Description: Ens rot brazo contrl
Ball Joint Mounting Type: Press In
Ball Joint Stud Type: Threaded
Bushing Material: Rubber
Bushings Included: Yes
Control Arm Color: Black
Control Arm Material: Forged Steel
Grease Fitting Included: Yes
Mounting Hardware Included: Yes
Pre-Greased: Yes
"""

result = model(text)
result
# Out:
# ''

# %%
from summarizer import Summarizer
from transformers import AlbertTokenizer, AlbertModel

text = """
Part Label: Suspension Control Arm And Ball Joint Assembly

Suspension Control Arm and Ball Joint Assembly
Extended Description:   Horquilla con Rotula parte delantera izquierda superior
Extended Description:   Bras de suspension assemble avec joint a rotule avant gauche superieur
Extended Description:   Suspension Control Arm and Ball Joint Assembly front left upper
Invoice Product Description: Bras com joint rotu
Invoice Product Description: Cntrl Arm w Ball Jt
Invoice Product Description: Ens rot brazo contrl
Ball Joint Mounting Type: Press In
Ball Joint Stud Type: Threaded
Bushing Material: Rubber
Bushings Included: Yes
Control Arm Color: Black
Control Arm Material: Forged Steel
Grease Fitting Included: Yes
Mounting Hardware Included: Yes
Pre-Greased: Yes
"""

albert_model = AlbertModel.from_pretrained('albert_xxlarge', output_hidden_states=True)
albert_tokenizer = AlbertTokenizer.from_pretrained('albert_xxlarge')
albert_model = Summarizer(custom_model=albert_model, custom_tokenizer=albert_tokenizer, random_state = 7)
output = albert_model(text, min_length=10, ratio=0.01)
print(output)
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     285     try:
# --> 286         response.raise_for_status()
#     287     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 404 Client Error: Not Found for url: https://huggingface.co/albert_xxlarge/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# RepositoryNotFoundError                   Traceback (most recent call last)
# ...
